# %% [markdown]
# # Emotion Detection

# %% [markdown]
# ## Importing libraries

# %%
import glob as glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D 
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from matplotlib import pyplot as plt

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.9.1

# %% [markdown]
# ## Exploring Dataset

# %%
from glob import glob

images = glob("train/**/**")

for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12, 12))
    plt.subplot(331 + i)
    plt.imshow(cv2.imread(image))
    plt.axis('off')

# %% [markdown]
# ## Preparing Data for Training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size, img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size, img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ## Defining Model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs, 32,(3,3))
    conv_2 = Convolution(inputs, 64,(5,5))
    conv_3 = Convolution(inputs, 128,(3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten,256)

    output = Dense(7, activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])

    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Batc  (None, 48, 48, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18,879,239
# Trainable params: 18,878,471
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# ## Initializing the Model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# ## Traning the Model

# %% [markdown]
# ##### The next cell takes time to complete

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6484 - accuracy: 0.3760
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 2165s 5s/step - loss: 1.6484 - accuracy: 0.3760 - val_loss: 1.8526 - val_accuracy: 0.3034
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3449 - accuracy: 0.4892
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 1667s 4s/step - loss: 1.3449 - accuracy: 0.4892 - val_loss: 1.6718 - val_accuracy: 0.3906
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1916 - accuracy: 0.5553
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 1392s 3s/step - loss: 1.1916 - accuracy: 0.5553 - val_loss: 1.5300 - val_accuracy: 0.4208
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0604 - accuracy: 0.6086
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 1538s 3s/step - loss: 1.0604 - accuracy: 0.6086 - val_loss: 1.6320 - val_accuracy: 0.3972
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9292 - accuracy: 0.6607
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 1930s 4s/step - loss: 0.9292 - accuracy: 0.6607 - val_loss: 1.5014 - val_accuracy: 0.4547
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8033 - accuracy: 0.7089
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 1703s 4s/step - loss: 0.8033 - accuracy: 0.7089 - val_loss: 1.6107 - val_accuracy: 0.4216
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.7572
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 1610s 4s/step - loss: 0.6876 - accuracy: 0.7572 - val_loss: 1.5272 - val_accuracy: 0.4848
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5865 - accuracy: 0.7943
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 1708s 4s/step - loss: 0.5865 - accuracy: 0.7943 - val_loss: 1.6691 - val_accuracy: 0.4785
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.8258
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 1531s 3s/step - loss: 0.5024 - accuracy: 0.8258 - val_loss: 1.8519 - val_accuracy: 0.4371
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8523
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 1641s 4s/step - loss: 0.4284 - accuracy: 0.8523 - val_loss: 1.7646 - val_accuracy: 0.4703
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8733
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 1261s 3s/step - loss: 0.3744 - accuracy: 0.8733 - val_loss: 1.7183 - val_accuracy: 0.4932
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.8879
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 1653s 4s/step - loss: 0.3356 - accuracy: 0.8879 - val_loss: 1.7872 - val_accuracy: 0.4898
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.8985
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 1216s 3s/step - loss: 0.3032 - accuracy: 0.8985 - val_loss: 1.8551 - val_accuracy: 0.4951
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9123
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 2072s 5s/step - loss: 0.2668 - accuracy: 0.9123 - val_loss: 1.8399 - val_accuracy: 0.5056
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9195
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 1681s 4s/step - loss: 0.2429 - accuracy: 0.9195 - val_loss: 2.0010 - val_accuracy: 0.4907

# %% [markdown]
# ## Model Evaluation

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 25s 212ms/step - loss: 2.0003 - accuracy: 0.4905
# [2.000298023223877, 0.49052661657333374]

# %% [markdown]
# #### Plotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# #### Saving Model

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
